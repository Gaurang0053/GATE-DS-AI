# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurang0053/GATE-DS-AI/blob/main/2nd_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Total 33 keywords in python.
#
# # All the other keword except True , False and none are in lower case.

# %% [markdown]
# :![Python-data-structure.jpg](data:image/jpeg;base64,...)

# %%
# implicit Conversion
a = 40
b = 20.67
sum= a + b
print(sum)
print(int(sum))
print(type(a))
# Out:
# 60.67
# 60
# <class 'int'>

# %%
# explicit Conversion
a = '123'
b = 20.67
sum= int(a) + b
print(sum)
# Out:
# 143.67000000000002

# %%
# explicit Conversion
a = '123'
b = 20
a= int(a) # string to int conversion
print(a+b)
# Out:
# 143

# %%
# Concatenation
a = '123'
b = 20
b= str(b) # int to string conversion
print(a+b)
# Out:
# 12320

# %% [markdown]
# # **Lists**

# %%
mylist=[65,'python',23.9,"learning",76] # list can be changed
print(mylist)
# Out:
# [65, 'python', 23.9, 'learning', 76]

# %% [markdown]
# # **Tuples**

# %%
mytuples=(95,'python',83.9,"learning",78) # tuple cant be changed
print(mytuples)
# Out:
# (95, 'python', 83.9, 'learning', 78)
